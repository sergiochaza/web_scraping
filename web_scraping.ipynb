# %% [markdown]
# <a href="https://colab.research.google.com/github/sergiochaza/web_scraping/blob/main/web_scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#BeutifulSoup
# !pip install bs4
# Out:
# Requirement already satisfied: bs4 in /usr/local/lib/python3.11/dist-packages (0.0.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from bs4) (4.13.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->bs4) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->bs4) (4.14.0)

# %% [markdown]
# WEB LOREAL
# https://salones-es.lorealprofessionnel.com/ar/cordoba

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
links=['https://salones-es.lorealprofessionnel.com/ar/santa-fe']
for i in range(2,9):
    links.append('https://salones-es.lorealprofessionnel.com/ar/santa-fe'+str(i))
len(links)
# Out:
# 8

# %%
links
# Out:
# ['https://salones-es.lorealprofessionnel.com/ar/santa-fe',
#  'https://salones-es.lorealprofessionnel.com/ar/santa-fe2',
#  'https://salones-es.lorealprofessionnel.com/ar/santa-fe3',
#  'https://salones-es.lorealprofessionnel.com/ar/santa-fe4',
#  'https://salones-es.lorealprofessionnel.com/ar/santa-fe5',
#  'https://salones-es.lorealprofessionnel.com/ar/santa-fe6',
#  'https://salones-es.lorealprofessionnel.com/ar/santa-fe7',
#  'https://salones-es.lorealprofessionnel.com/ar/santa-fe8']

# %%
direcciones = []
nombres = []

# %%
for i in links:
    url = i
    r = requests.get(url)
    soup = BeautifulSoup(r.content, 'html.parser')
    # Buscar los nombres de los salones
    for j in soup.find_all('span', class_="lf-location-default__content__container__header__title__text lf-geo-divisions__top__wrapper__main__locations__list__location__content__container__header__title__text"):
        nombres.append(j.text)

    # Buscar las direcciones
    for k in soup.find_all('span', class_="lf-parts-address__content__street lf-location-default__content__container__address__content__street lf-geo-divisions__top__wrapper__main__locations__list__location__content__container__address__content__street"):
        direcciones.append(k.text)

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="es">
# <head>
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="xO8_oPasrUAhE_XPehr8CIhLwvvMBIYr3OcaOcjDHRk" name="google-site-verification"/>
# <!-- OneTrust Cookies Consent Notice start -->
# <script charset="UTF-8" data-document-language="true" data-domain-script="7ceb23c4-6518-49e9-98e3-227ed2a166a9" src="https://cdn.cookielaw.org/scripttemplates/otSDKStub.js" type="text/javascript">
# </script>
# <script type="text/javascript">
#     function OptanonWrapper() {
#             }
# </script> <!-- OneTrust Cookies Consent Notice end -->
# <title>Salones de peluquería L’Oréal Professionnel en Argentina : su peluquero L’Oréal Professionnel</title>
# <meta content="Salones de peluquería L’Oréal Professionnel en Argentina : su peluquero L’Oréal Professionnel" name="title"/>
# <meta content="L’Oréal Professionnel Argentina : descubra qué salones se encuentran cerca, los horarios de apertura y la información práctica sobre su peluquería L’Oréal Professionnel." name="description"/>
# <link href="https://salones-es.lorealprofessionnel.com/ar?page=2" rel="next"/>
# <link href="https://hair-salon-en.lorealprofessionnel.com/ar" hreflang="x-default" rel="alternate">
# <link href="https://hair-salon-en.lorealprofessionnel.com/ar" hreflang="en" rel="alternate"/>
# <link href="https://salon-fr.lorealprofessionnel.com/ar" hreflang="fr" rel="alternate"/>
# <link href="https://friseur-de.lorealprofessionnel.com/ar" hreflang="de" rel="alternate"/>
# <link href="https://kommotiria-gr.lorealprofessionnel.com/ar" hreflang="el" rel="alternate"/>
# <link href="https://kapper-nl.lorealprofessionnel.com/ar" hreflang="nl" rel="alternate"/>
# <link href="https://salone-it.lorealprofessionnel.com/ar" hreflang="it" rel="alternate"/>
# <link href="https://salones-es.lorealprofessionnel.com/ar" hreflang="es" rel="alternate"/>
# <link href="https://cabeleireiros-pt.lorealprofessionnel.com/ar" hreflang="pt" rel="alternate"/>
# <link href="https://salon-ar.lorealprofessionnel.com/ar" hreflang="ar" rel="alternate"/>
# <link href="https://saloane-ro.lorealprofessionnel.com/ar" hreflang="ro" rel="alternate"/>
# <link href="https://hair-salon-jp.lorealprofessionnel.com/ar" hreflang="ja" rel="alternate"/>
# <link href="https://salony-pl.lorealprofessionnel.com/ar" hreflang="pl" rel="alternate"/>
# <link href="https://storage.leadformance.com/assets/production-front-offices/v3-lOrealProfessionnel/v0.22.0/humans.txt" rel="author"/>
# <link href="https://storage.leadformance.com/assets/production-front-offices/v3-lOrealProfessionnel/v0.22.0/build/geo-divisions.min.css" rel="stylesheet" title="main"/>
# <link disabled="" href="https://storage.leadformance.com/assets/production-front-offices/v3-lOrealProfessionnel/v0.22.0/build/geo-divisions-wcag.min.css" rel="stylesheet" title="wcag"/>
# <link href="https://storage.leadformance.com/assets/production-front-offices/v3-lOrealProfessionnel/v0.22.0/assets/favicon/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="https://storage.leadformance.com/assets/production-front-offices/v3-lOrealProfessionnel/v0.22.0/assets/favicon/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="https://storage.leadformance.com/assets/production-front-offices/v3-lOrealProfessionnel/v0.22.0/assets/favicon/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="https://storage.leadformance.com/assets/production-front-offices/v3-lOrealProfessionnel/v0.22.0/assets/favicon/site.webmanifest" rel="manifest"/>
# <link color="#333333" href="https://storage.leadformance.com/assets/production-front-offices/v3-lOrealProfessionnel/v0.22.0/assets/favicon/safari-pinned-tab.svg" rel="mask-icon"/>
# <link href="https://storage.leadformance.com/assets/production-front-offices/v3-lOrealProfessionnel/v0.22.0/assets/favicon/favicon.ico" rel="shortcut icon"/>
# <meta content="#333333" name="msapplication-TileColor"/>
# <meta content="https://storage.leadformance.com/assets/production-front-offices/v3-lOrealProfessionnel/v0.22.0/assets/favicon/browserconfig.xml" name="msapplication-config"/>
# <meta content="#333333" name="theme-color"/>
# <script>
#     var dataLayer = window['dataLayer'] || [];
#     dataLayer.push ({
#         brand: 'LP',
#         language: 'es',
#         country: 'es',
#         siteTypeLevel: 'testing',
#         pageCategory: 'salon locator',
#         cid: ''
#     });
# </script>
# <!-- Google Tag Manager GTM-NG79HLS -->
# <script class="optanon-category-2" type="text/plain">
#         (function(w,d,s,l,i){
#             w[l]=w[l]||[];w[l].push({'gtm.start': new Date().getTime(),event:'gtm.js'});
#             var f=d.getElementsByTagName(s)[0], j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';
#             j.async=true;j.src= '//www.googletagmanager.com/gtm.js?id='+i+dl;
#             f.parentNode.insertBefore(j,f);
#         })
#         (window,document,'script','dataLayer','GTM-NG79HLS');
#     </script>
# <!-- Google Tag Manager GTM-P7QHLH -->
# <script>
#             (function(w,d,s,l,i){
#                 w[l]=w[l]||[];w[l].push({'gtm.start': new Date().getTime(),event:'gtm.js'});
#                 var f=d.getElementsByTagName(s)[0], j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';
#                 j.async=true;j.src= '//www.googletagmanager.com/gtm.js?id='+i+dl;
#                 f.parentNode.insertBefore(j,f);
#             })
#             (window,document,'script','dataLayer','GTM-P7QHLH');
#         </script>
# </link></head>
# <body data-bridge-tracking-client-id="5e15eee0ec40d1c7741dd946" data-bridge-tracking-env="production-front-offices" data-bridge-tracking-front-office-id="60be0ce76a306d12b9da77d8" data-bridge-tracking-locale="es" data-bridge-tracking-location-id="" id="lf-body">
# <div id="lf-body-large-wrapper">
# <!-- Google Tag Manager noscript GTM-P7QHLH -->
# <noscript>
# <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-P7QHLH" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript>
# <!-- Google Tag Manager noscript GTM-NG79HLS -->
# <noscript>
# <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-NG79HLS" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript>
# <ul class="lf-skip-content">
# <li class="lf-skip-content__item"><a class="lf-skip-content__item__link" data-lf-tracking='{"bind":"click","label":"search","action":"","category":"Skip to Content"}' href="#lf-search">saltar a la búsqueda principal</a></li><li class="lf-skip-content__item"><a class="lf-skip-content__item__link" data-lf-tracking='{"bind":"click","label":"content","action":"","category":"Skip to Content"}' href="#lf-content">saltar al contenido principal</a></li><li class="lf-skip-content__item"><a class="lf-skip-content__item__link" data-lf-tracking='{"bind":"click","label":"footer","action":"","category":"Skip to Content"}' href="#lf-footer">saltar al pie de página principal</a></li></ul>
# <section aria-describedby="description-notification" aria-labelledby="title-notification" class="lf-notification-default inactive" data-lf-notification="" role="alert">
# <em aria-hidden="true" class="lf-notification-default__icon" data-lf-notification-icon=""></em>
# <p class="lf-notification-default__title" data-lf-notification-title="" id="title-notification"></p>
# <p class="lf-notification-default__message" data-lf-notification-msg="" id="description-notification"></p>
# </section>
# <header data-lf-header="">
# <nav class="lf-header-optimum" id="lf-header-optimum">
# <div class="lf-header-optimum__main lf-header-optimum__main--container">
# <a class="lf-header-optimum__main__logo" data-lf-client-tracking="{'event': 'uaevent', 'ecommerce': 'undefined', 'eventCategory': 'main menu navigation', 'eventAction': 'select::header', 'eventLabel': 'logo', 'event_name': 'logo_click', 'click_area': 'header'}" data-lf-header-logo="" data-lf-tracking='{"bind":"click","label":"logo L\u2019Or\u00e9al Professionnel","action":"","category":"Header External Links"}' href="/">
# <img alt="Logo de L’Oréal Professionnel" class="lf-header-optimum__main__logo__image" src="https://storage.leadformance.com/assets/production-front-offices/v3-lOrealProfessionnel/v0.22.0/assets/images/client/brand-logo.png"/>
# </a>
# <div class="lf-header-optimum__main__menu lf-hidden" data-lf-header-menu="" id="lf-header-nav">
# <div class="lf-header-optimum__main__menu__content" data-lf-header-menu-items="">
# <ul class="lf-header-optimum__main__menu__content__list"></ul> </div>
# </div>
# </div>
# </nav>
# </header>
# <div id="lf-body-wrapper">
# <div class="lf">
# <div class="lf-geo-divisions" data-e2e-geo-divisions="">
# <section class="lf-geo-divisions__find" data-lf-search-wrapper="">
# <div class="lf-geo-divisions__find__navigation" id="lf-geo-divisions-top-nav">
# <div class="lf-geo-divisions__find__navigation__wrapper">
# <div class="lf-search-modal lf-geo-divisions__find__navigation__wrapper__search" id="lf-search">
# <button class="lf-cta-button lf-search-modal__trigger lf-geo-divisions__find__navigation__wrapper__search__trigger" data-e2e-search-modal-btn="" data-lf-tracking='{"bind":"click","label":"Buscar ","action":"","category":"Buscar "}' data-micromodal-trigger="lf-search-modal" type="button">
# <em aria-hidden="true" class="lf-cta-button__icon lf-cta-button__icon--left bridge-icon-reputation-search lf-search-modal__trigger__icon lf-search-modal__trigger__icon--left lf-geo-divisions__find__navigation__wrapper__search__trigger__icon lf-geo-divisions__find__navigation__wrapper__search__trigger__icon--left"></em><span class="lf-cta-button__label lf-search-modal__trigger__label lf-geo-divisions__find__navigation__wrapper__search__trigger__label">
#                                                 Buscar
#                         </span></button>
# <div aria-hidden="true" class="lf-modal-default lf-modal-default--right lf-search-modal__main lf-geo-divisions__find__navigation__wrapper__search__main" id="lf-search-modal">
# <div class="lf-modal-default__container lf-search-modal__main__container lf-geo-divisions__find__navigation__wrapper__search__main__container" data-micromodal-close="" tabindex="-1">
# <section aria-labelledby="lf-search-modal-title" aria-live="assertive" aria-modal="true" class="lf-modal-default__container__content lf-search-modal__main__container__content lf-geo-divisions__find__navigation__wrapper__search__main__container__content" role="dialog">
# <header class="lf-modal-default__container__content__header lf-search-modal__main__container__content__header lf-geo-divisions__find__navigation__wrapper__search__main__container__content__header">
# <button class="lf-modal-default__container__content__header__close lf-search-modal__main__container__content__header__close lf-geo-divisions__find__navigation__wrapper__search__main__container__content__header__close" data-micromodal-close="" type="button">
# <em class="bridge-icon-reputation-close lf-modal-default__container__content__header__close__icon lf-search-modal__main__container__content__header__close__icon lf-geo-divisions__find__navigation__wrapper__search__main__container__content__header__close__icon" data-micromodal-close=""></em>
# <em class="bridge-icon-reputation-arrow-right lf-modal-default__container__content__header__close__icon lf-modal-default__container__content__header__close__icon--mobile lf-search-modal__main__container__content__header__close__icon lf-geo-divisions__find__navigation__wrapper__search__main__container__content__header__close__icon" data-micromodal-close=""></em>
# <span class="sr-only">Cerrado</span>
# </button>
# <div class="lf-modal-default__container__content__header__title lf-search-modal__main__container__content__header__title lf-geo-divisions__find__navigation__wrapper__search__main__container__content__header__title" id="lf-search-modal-title">Escriba la ubicación para buscar un salón</div>
# </header>
# <div class="lf-modal-default__container__content__body lf-search-modal__main__container__content__body lf-geo-divisions__find__navigation__wrapper__search__main__container__content__body" id="lf-search-modal-content">
# <form action="/search" aria-label="Escriba la ubicación para buscar un salón" class="lf-search-modal__main__container__content__body__default__form lf-modal-default__container__content__body__default__main__container__content__body__default__form lf-search-modal__main__container__content__body__default__main__container__content__body__default__form lf-geo-divisions__find__navigation__wrapper__search__main__container__content__body__default__main__container__content__body__default__form" data-lf-modal-id="lf-search-modal-form" data-lf-search-form="" data-lf-tracking='{"bind":"submit","label":"","action":"","category":"Search"}' id="lf-search-modal-form" role="search">
# <div class="lf-search-modal__main__container__content__body__default__form__find lf-modal-default__container__content__body__default__main__container__content__body__default__form__find lf-search-modal__main__container__content__body__default__main__container__content__body__default__form__find lf-geo-divisions__find__navigation__wrapper__search__main__container__content__body__default__main__container__content__body__default__form__find">
# <div class="lf-search-modal__main__container__content__body__default__form__find__content">
# <div class="lf-search-modal__main__container__content__body__default__form__find__content__top lf-modal-default__container__content__body__default__main__container__content__body__default__form__find__content__top lf-search-modal__main__container__content__body__default__main__container__content__body__default__form__find__content__top lf-geo-divisions__find__navigation__wrapper__search__main__container__content__body__default__main__container__content__body__default__form__find__content__top">
# <div class="lf-search-country lf-modal-default__container__content__body__default__form__find__content__top__country lf-search-modal__main__container__content__body__default__form__find__content__top__country lf-geo-divisions__find__navigation__wrapper__search__main__container__content__body__default__form__find__content__top__country" data-lf-search-country="" id="lf-search-country">
# <div class="lf-search-country__select lf-modal-default__container__content__body__default__form__find__content__top__country__select lf-search-modal__main__container__content__body__default__form__find__content__top__country__select lf-geo-divisions__find__navigation__wrapper__search__main__container__content__body__default__form__find__content__top__country__select">
# <span class="lf-search-country__select__helper" data-lf-countries-helper="" id="lf-search-country-helper">Seleccione al menos un país antes de iniciar la búsqueda</span>
# <select data-lf-country-error="Seleccione al menos un país antes de iniciar la búsqueda" id="country-input" multiple="" name="countries[]">
# <option data-default="true" data-unique="true" value="">Seleccione</option>
# <option data-lf-country-code="DE" data-lf-country-text="Alemania" value="DE">Alemania</option>
# <option data-lf-country-code="AD" data-lf-country-text="Andorra" value="AD">Andorra</option>
# <option data-lf-country-code="SA" data-lf-country-text="Arabia Saudí" value="SA">Arabia Saudí</option>
# <option data-lf-country-code="AR" data-lf-country-text="Argentina" value="AR">Argentina</option>
# <option data-lf-country-code="AU" data-lf-country-text="Australia" value="AU">Australia</option>
# <option data-lf-country-code="AT" data-lf-country-text="Austria" value="AT">Austria</option>
# <option data-lf-country-code="BG" data-lf-country-text="Bulgaria" value="BG">Bulgaria</option>
# <option data-lf-country-code="BE" data-lf-country-text="Bélgica" value="BE">Bélgica</option>
# <option data-lf-country-code="CA" data-lf-country-text="Canadá" value="CA">Canadá</option>
# <option data-lf-country-code="CL" data-lf-country-text="Chile" value="CL">Chile</option>
# <option data-lf-country-code="CO" data-lf-country-text="Colombia" value="CO">Colombia</option>
# <option data-lf-country-code="HR" data-lf-country-text="Croacia" value="HR">Croacia</option>
# <option data-lf-country-code="DK" data-lf-country-text="Dinamarca" value="DK">Dinamarca</option>
# <option data-lf-country-code="AE" data-lf-country-text="Emiratos Árabes Unidos" value="AE">Emiratos Árabes Unidos</option>
# <option data-lf-country-code="ES" data-lf-country-text="España" value="ES">España</option>
# <option data-lf-country-code="FI" data-lf-country-text="Finlandia" value="FI">Finlandia</option>
# <option data-lf-country-code="FR" data-lf-country-text="Francia" value="FR">Francia</option>
# <option data-lf-country-code="GR" data-lf-country-text="Grecia" value="GR">Grecia</option>
# <option data-lf-country-code="GG" data-lf-country-text="Guernsey" value="GG">Guernsey</option>
# <option data-lf-country-code="IN" data-lf-country-text="India" value="IN">India</option>
# <option data-lf-country-code="IE" data-lf-country-text="Irlanda" value="IE">Irlanda</option>
# <option data-lf-country-code="IT" data-lf-country-text="Italia" value="IT">Italia</option>
# <option data-lf-country-code="JP" data-lf-country-text="Japón" value="JP">Japón</option>
# <option data-lf-country-code="JE" data-lf-country-text="Jersey" value="JE">Jersey</option>
# <option data-lf-country-code="LI" data-lf-country-text="Liechtenstein" value="LI">Liechtenstein</option>
# <option data-lf-country-code="LU" data-lf-country-text="Luxemburgo" value="LU">Luxemburgo</option>
# <option data-lf-country-code="MX" data-lf-country-text="México" value="MX">México</option>
# <option data-lf-country-code="MC" data-lf-country-text="Mónaco" value="MC">Mónaco</option>
# <option data-lf-country-code="NO" data-lf-country-text="Noruega" value="NO">Noruega</option>
# <option data-lf-country-code="NL" data-lf-country-text="Países Bajos" value="NL">Países Bajos</option>
# <option data-lf-country-code="PE" data-lf-country-text="Perú" value="PE">Perú</option>
# <option data-lf-country-code="PT" data-lf-country-text="Portugal" value="PT">Portugal</option>
# <option data-lf-country-code="GB" data-lf-country-text="Reino Unido" value="GB">Reino Unido</option>
# <option data-lf-country-code="RO" data-lf-country-text="Rumanía" value="RO">Rumanía</option>
# <option data-lf-country-code="SM" data-lf-country-text="San Marino" value="SM">San Marino</option>
# <option data-lf-country-code="RS" data-lf-country-text="Serbia" value="RS">Serbia</option>
# <option data-lf-country-code="SE" data-lf-country-text="Suecia" value="SE">Suecia</option>
# <option data-lf-country-code="CH" data-lf-country-text="Suiza" value="CH">Suiza</option>
# <option data-lf-country-code="UY" data-lf-country-text="Uruguay" value="UY">Uruguay</option>
# </select>
# </div>
# </div>
# <div aria-hidden="true" class="lf-search-country-error lf-modal-default__container__content__body__default__form__find__content__top__country lf-search-modal__main__container__content__body__default__form__find__content__top__country lf-geo-divisions__find__navigation__wrapper__search__main__container__content__body__default__form__find__content__top__country lf-form-helper" data-lf-form-helper="" id="lf-forms-country-error" role="alert"></div>
# </div>
# <div class="lf-search-modal__main__container__content__body__default__form__find__content__bottom lf-modal-default__container__content__body__default__main__container__content__body__default__form__find__content__bottom lf-search-modal__main__container__content__body__default__main__container__content__body__default__form__find__content__bottom lf-geo-divisions__find__navigation__wrapper__search__main__container__content__body__default__main__container__content__body__default__form__find__content__bottom">
# <div class="lf-search-modal__main__container__content__body__default__form__find__content__bottom__query icon-prefix lf-modal-default__container__content__body__default__main__container__content__body__default__form__find__content__bottom__query lf-search-modal__main__container__content__body__default__main__container__content__body__default__form__find__content__bottom__query lf-geo-divisions__find__navigation__wrapper__search__main__container__content__body__default__main__container__content__body__default__form__find__content__bottom__query">
# <button class="lf-cta-button lf-search-geolocation lf-modal-default__container__content__body__default__form__find__content__bottom__query__geolocation lf-search-modal__main__container__content__body__default__form__find__content__bottom__query__geolocation lf-geo-divisions__find__navigation__wrapper__search__main__container__content__body__default__form__find__content__bottom__query__geolocation" data-lf-geolocation-button="" data-lf-msg-error="Se ha producido un error durante la geolocalización" data-lf-msg-timeout="No es posible definir su posición (límite de tiempo)" data-lf-msg-title="La geolocalización ha fallado" data-lf-msg-warning="Debe habilitar su geolocalización" data-lf-search-geolocation-status="" data-lf-tracking='{"bind":"click","label":"Cerca de mi ubicaci\u00f3n ","action":"","category":"Search"}' id="lf-search-geolocation" type="button">
# <em aria-hidden="true" class="lf-cta-button__icon lf-cta-button__icon--left bridge-icon-reputation-geolocation lf-search-geolocation__icon lf-search-geolocation__icon--left lf-modal-default__container__content__body__default__form__find__content__bottom__query__geolocation__icon lf-modal-default__container__content__body__default__form__find__content__bottom__query__geolocation__icon--left lf-search-modal__main__container__content__body__default__form__find__content__bottom__query__geolocation__icon lf-search-modal__main__container__content__body__default__form__find__content__bottom__query__geolocation__icon--left lf-geo-divisions__find__navigation__wrapper__search__main__container__content__body__default__form__find__content__bottom__query__geolocation__icon lf-geo-divisions__find__navigation__wrapper__search__main__container__content__body__default__form__find__content__bottom__query__geolocation__icon--left"></em><span class="lf-cta-button__label lf-search-geolocation__label lf-modal-default__container__content__body__default__form__find__content__bottom__query__geolocation__label lf-search-modal__main__container__content__body__default__form__find__content__bottom__query__geolocation__label lf-geo-divisions__find__navigation__wrapper__search__main__container__content__body__default__form__find__content__bottom__query__geolocation__label">
#                                                 Cerca de mi ubicación
#                         </span><span class="sr-only">, encontrar una salón L’Oréal Professionnel </span></button>
# <label class="lf-search-modal__main__container__content__body__default__form__find__content__bottom__query__label lf-modal-default__container__content__body__default__main__container__content__body__default__form__find__content__bottom__query__label lf-search-modal__main__container__content__body__default__main__container__content__body__default__form__find__content__bottom__query__label lf-geo-divisions__find__navigation__wrapper__search__main__container__content__body__default__main__container__content__body__default__form__find__content__bottom__query__label" for="lf-search-default-query">Código postal, ciudad...</label>
# <input class="lf-search-modal__main__container__content__body__default__form__find__content__bottom__query__input browser-default lf-modal-default__container__content__body__default__main__container__content__body__default__form__find__content__bottom__query__input lf-search-modal__main__container__content__body__default__main__container__content__body__default__form__find__content__bottom__query__input lf-geo-divisions__find__navigation__wrapper__search__main__container__content__body__default__main__container__content__body__default__form__find__content__bottom__query__input" data-e2e-search-query="" data-lf-search-query="" id="lf-search-default-query" name="query" placeholder="Código postal, ciudad..." type="text" value=""/>
# </div>
# <button class="lf-cta-button lf-modal-default__container__content__body__default__form__find__content__bottom__submit lf-search-modal__main__container__content__body__default__form__find__content__bottom__submit lf-geo-divisions__find__navigation__wrapper__search__main__container__content__body__default__form__find__content__bottom__submit" data-e2e-search-submit="" type="submit">
# <em aria-hidden="true" class="lf-cta-button__icon lf-cta-button__icon--left bridge-icon-reputation-search lf-modal-default__container__content__body__default__form__find__content__bottom__submit__icon lf-modal-default__container__content__body__default__form__find__content__bottom__submit__icon--left lf-search-modal__main__container__content__body__default__form__find__content__bottom__submit__icon lf-search-modal__main__container__content__body__default__form__find__content__bottom__submit__icon--left lf-geo-divisions__find__navigation__wrapper__search__main__container__content__body__default__form__find__content__bottom__submit__icon lf-geo-divisions__find__navigation__wrapper__search__main__container__content__body__default__form__find__content__bottom__submit__icon--left"></em><span class="lf-cta-button__label lf-modal-default__container__content__body__default__form__find__content__bottom__submit__label lf-search-modal__main__container__content__body__default__form__find__content__bottom__submit__label lf-geo-divisions__find__navigation__wrapper__search__main__container__content__body__default__form__find__content__bottom__submit__label">
#                                                 Buscar
#                         </span><span class="sr-only">un salón L’Oréal Professionnel </span></button>
# <div class="lf-search-modal__main__container__content__body__default__form__find__content__bottom__coordinates lf-modal-default__container__content__body__default__main__container__content__body__default__form__find__content__bottom__coordinates lf-search-modal__main__container__content__body__default__main__container__content__body__default__form__find__content__bottom__coordinates lf-geo-divisions__find__navigation__wrapper__search__main__container__content__body__default__main__container__content__body__default__form__find__content__bottom__coordinates">
# <input data-lf-search-latitude="" name="lat" type="hidden" value=""/>
# <input data-lf-search-longitude="" name="lon" type="hidden" value=""/>
# <input data-lf-search-geo="" name="geo" type="hidden" value="0"/>
# </div>
# <div class="lf-autocomplete-algolia lf-modal-default__container__content__body__default__form__find__content__bottom__algolia lf-search-modal__main__container__content__body__default__form__find__content__bottom__algolia lf-geo-divisions__find__navigation__wrapper__search__main__container__content__body__default__form__find__content__bottom__algolia" data-lf-autocomplete="" data-lf-autocomplete-locale="es">
# <div class="lf-autocomplete-algolia__dataset lf-modal-default__container__content__body__default__form__find__content__bottom__algolia__dataset lf-search-modal__main__container__content__body__default__form__find__content__bottom__algolia__dataset lf-geo-divisions__find__navigation__wrapper__search__main__container__content__body__default__form__find__content__bottom__algolia__dataset">
# <div class="lf-autocomplete-algolia__dataset__title lf-modal-default__container__content__body__default__form__find__content__bottom__algolia__dataset__title lf-search-modal__main__container__content__body__default__form__find__content__bottom__algolia__dataset__title lf-geo-divisions__find__navigation__wrapper__search__main__container__content__body__default__form__find__content__bottom__algolia__dataset__title" data-lf-autocomplete-places-header="">
#                 Ciudades
#             </div>
# <div class="lf-autocomplete-algolia__dataset__suggestion lf-modal-default__container__content__body__default__form__find__content__bottom__algolia__dataset__suggestion lf-search-modal__main__container__content__body__default__form__find__content__bottom__algolia__dataset__suggestion lf-geo-divisions__find__navigation__wrapper__search__main__container__content__body__default__form__find__content__bottom__algolia__dataset__suggestion" data-lf-autocomplete-places-suggestion="">
# <div class="lf-autocomplete-algolia__dataset__suggestion__icon lf-modal-default__container__content__body__default__form__find__content__bottom__algolia__dataset__suggestion__icon lf-search-modal__main__container__content__body__default__form__find__content__bottom__algolia__dataset__suggestion__icon lf-geo-divisions__find__navigation__wrapper__search__main__container__content__body__default__form__find__content__bottom__algolia__dataset__suggestion__icon">
# <em aria-label="tipo de resultado: places" class="bridge-icon-reputation-city" role="img"></em>
# </div>
# <div class="lf-autocomplete-algolia__dataset__suggestion__infos lf-modal-default__container__content__body__default__form__find__content__bottom__algolia__dataset_suggestion_infos lf-search-modal__main__container__content__body__default__form__find__content__bottom__algolia__dataset_suggestion_infos lf-geo-divisions__find__navigation__wrapper__search__main__container__content__body__default__form__find__content__bottom__algolia__dataset_suggestion_infos">
# <span class="lf-autocomplete-algolia__dataset__suggestion__infos__name lf-modal-default__container__content__body__default__form__find__content__bottom__algolia__dataset_suggestion_infos__name lf-search-modal__main__container__content__body__default__form__find__content__bottom__algolia__dataset_suggestion_infos__name lf-geo-divisions__find__navigation__wrapper__search__main__container__content__body__default__form__find__content__bottom__algolia__dataset_suggestion_infos__name">{name}</span>
# <span class="lf-autocomplete-algolia__dataset__suggestion__infos__address lf-modal-default__container__content__body__default__form__find__content__bottom__algolia__dataset_suggestion_infos__address lf-search-modal__main__container__content__body__default__form__find__content__bottom__algolia__dataset_suggestion_infos__address lf-geo-divisions__find__navigation__wrapper__search__main__container__content__body__default__form__find__content__bottom__algolia__dataset_suggestion_infos__address">{postalCode} {country}</span>
# </div>
# </div>
# </div>
# <div class="lf-autocomplete-algolia__dataset lf-modal-default__container__content__body__default__form__find__content__bottom__algolia__dataset lf-search-modal__main__container__content__body__default__form__find__content__bottom__algolia__dataset lf-geo-divisions__find__navigation__wrapper__search__main__container__content__body__default__form__find__content__bottom__algolia__dataset">
# <div class="lf-autocomplete-algolia__dataset__title lf-modal-default__container__content__body__default__form__find__content__bottom__algolia__dataset__title lf-search-modal__main__container__content__body__default__form__find__content__bottom__algolia__dataset__title lf-geo-divisions__find__navigation__wrapper__search__main__container__content__body__default__form__find__content__bottom__algolia__dataset__title" data-lf-autocomplete-locations-header="">
#                 Salones
#             </div>
# <div class="lf-autocomplete-algolia__dataset__suggestion lf-modal-default__container__content__body__default__form__find__content__bottom__algolia__dataset__suggestion lf-search-modal__main__container__content__body__default__form__find__content__bottom__algolia__dataset__suggestion lf-geo-divisions__find__navigation__wrapper__search__main__container__content__body__default__form__find__content__bottom__algolia__dataset__suggestion" data-lf-autocomplete-locations-suggestion="">
# <div class="lf-autocomplete-algolia__dataset__suggestion__icon lf-modal-default__container__content__body__default__form__find__content__bottom__algolia__dataset__suggestion__icon lf-search-modal__main__container__content__body__default__form__find__content__bottom__algolia__dataset__suggestion__icon lf-geo-divisions__find__navigation__wrapper__search__main__container__content__body__default__form__find__content__bottom__algolia__dataset__suggestion__icon">
# <em aria-label="tipo de resultado: locations" class="bridge-icon-reputation-store" role="img"></em>
# </div>
# <div class="lf-autocomplete-algolia__dataset__suggestion__infos lf-modal-default__container__content__body__default__form__find__content__bottom__algolia__dataset_suggestion_infos lf-search-modal__main__container__content__body__default__form__find__content__bottom__algolia__dataset_suggestion_infos lf-geo-divisions__find__navigation__wrapper__search__main__container__content__body__default__form__find__content__bottom__algolia__dataset_suggestion_infos">
# <span class="lf-autocomplete-algolia__dataset__suggestion__infos__name lf-modal-default__container__content__body__default__form__find__content__bottom__algolia__dataset_suggestion_infos__name lf-search-modal__main__container__content__body__default__form__find__content__bottom__algolia__dataset_suggestion_infos__name lf-geo-divisions__find__navigation__wrapper__search__main__container__content__body__default__form__find__content__bottom__algolia__dataset_suggestion_infos__name">{name}</span>
# <span class="lf-autocomplete-algolia__dataset__suggestion__infos__address lf-modal-default__container__content__body__default__form__find__content__bottom__algolia__dataset_suggestion_infos__address lf-search-modal__main__container__content__body__default__form__find__content__bottom__algolia__dataset_suggestion_infos__address lf-geo-divisions__find__navigation__wrapper__search__main__container__content__body__default__form__find__content__bottom__algolia__dataset_suggestion_infos__address">{city}, {postalCode} {country}</span>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="lf-search-filters" id="lf-search-filters">
# <div class="lf-search-filters__header lf-modal-default__container__content__body__default__form__filters__header lf-search-modal__main__container__content__body__default__form__filters__header lf-geo-divisions__find__navigation__wrapper__search__main__container__content__body__default__form__filters__header">
# <div class="lf-search-filters__header__title lf-modal-default__container__content__body__default__form__filters__header__title lf-search-modal__main__container__content__body__default__form__filters__header__title lf-geo-divisions__find__navigation__wrapper__search__main__container__content__body__default__form__filters__header__title">
# <span>Seleccione uno o varios filtros</span>
# </div>
# </div>
# <div class="lf-search-filters__content lf-modal-default__container__content__body__default__form__filters__content lf-search-modal__main__container__content__body__default__form__filters__content lf-geo-divisions__find__navigation__wrapper__search__main__container__content__body__default__form__filters__content">
# <div class="lf-search-filters__content__group lf-modal-default__container__content__body__default__form__filters__content__group lf-search-modal__main__container__content__body__default__form__filters__content__group lf-geo-divisions__find__navigation__wrapper__search__main__container__content__body__default__form__filters__content__group">
# <div class="lf-search-filters__content__group__title lf-modal-default__container__content__body__default__form__filters__content__group__title lf-search-modal__main__container__content__body__default__form__filters__content__group__title lf-geo-divisions__find__navigation__wrapper__search__main__container__content__body__default__form__filters__content__group__title">Nuestros servicios</div>
# <ul class="lf-search-filters__content__group__list lf-modal-default__container__content__body__default__form__filters__content__group__list lf-search-modal__main__container__content__body__default__form__filters__content__group__list lf-geo-divisions__find__navigation__wrapper__search__main__container__content__body__default__form__filters__content__group__list" role="listbox">
# <li class="lf-search-filters__content__group__list__item lf-modal-default__container__content__body__default__form__filters__content__group__list__item lf-search-modal__main__container__content__body__default__form__filters__content__group__list__item lf-geo-divisions__find__navigation__wrapper__search__main__container__content__body__default__form__filters__content__group__list__item" role="option">
# <input class="lf-search-filters__content__group__list__item__input lf-modal-default__container__content__body__default__form__filters__content__group__list__item__input lf-search-modal__main__container__content__body__default__form__filters__content__group__list__item__input lf-geo-divisions__find__navigation__wrapper__search__main__container__content__body__default__form__filters__content__group__list__item__input" data-lf-filter-name="french balayage" data-lf-filters-category="nuestros servicios" data-lf-filters-input="" id="61692167dc0da7459b1796df" name="filters[Nuestros servicios][]" type="checkbox" value="61692167dc0da7459b1796df"/>
# <label class="lf-search-filters__content__group__list__item__label lf-modal-default__container__content__body__default__form__filters__content__group__list__item__label lf-search-modal__main__container__content__body__default__form__filters__content__group__list__item__label lf-geo-divisions__find__navigation__wrapper__search__main__container__content__body__default__form__filters__content__group__list__item__label" data-lf-filters-label="" for="61692167dc0da7459b1796df">
# <em aria-labelledby="61692167dc0da7459b1796df" class="lf-search-filters__content__group__list__item__label__icon lf-modal-default__container__content__body__default__form__filters__content__group__list__item__label__icon lf-search-modal__main__container__content__body__default__form__filters__content__group__list__item__label__icon lf-geo-divisions__find__navigation__wrapper__search__main__container__content__body__default__form__filters__content__group__list__item__label__icon" role="img"></em>
# <span class="lf-search-filters__content__group__list__item__label__text lf-modal-default__container__content__body__default__form__filters__content__group__list__item__label__text lf-search-modal__main__container__content__body__default__form__filters__content__group__list__item__label__text lf-geo-divisions__find__navigation__wrapper__search__main__container__content__body__default__form__filters__content__group__list__item__label__text">FRENCH BALAYAGE</span>
# </label>
# </li>
# <li class="lf-search-filters__content__group__list__item lf-modal-default__container__content__body__default__form__filters__content__group__list__item lf-search-modal__main__container__content__body__default__form__filters__content__group__list__item lf-geo-divisions__find__navigation__wrapper__search__main__container__content__body__default__form__filters__content__group__list__item" role="option">
# <input class="lf-search-filters__content__group__list__item__input lf-modal-default__container__content__body__default__form__filters__content__group__list__item__input lf-search-modal__main__container__content__body__default__form__filters__content__group__list__item__input lf-geo-divisions__find__navigation__wrapper__search__main__container__content__body__default__form__filters__content__group__list__item__input" data-lf-filter-name="french glossing" data-lf-filters-category="nuestros servicios" data-lf-filters-input="" id="61692172dc0da7d8c6179729" name="filters[Nuestros servicios][]" type="checkbox" value="61692172dc0da7d8c6179729"/>
# <label class="lf-search-filters__content__group__list__item__label lf-modal-default__container__content__body__default__form__filters__content__group__list__item__label lf-search-modal__main__container__content__body__default__form__filters__content__group__list__item__label lf-geo-divisions__find__navigation__wrapper__search__main__container__content__body__default__form__filters__content__group__list__item__label" data-lf-filters-label="" for="61692172dc0da7d8c6179729">
# <em aria-labelledby="61692172dc0da7d8c6179729" class="lf-search-filters__content__group__list__item__label__icon lf-modal-default__container__content__body__default__form__filters__content__group__list__item__label__icon lf-search-modal__main__container__content__body__default__form__filters__content__group__list__item__label__icon lf-geo-divisions__find__navigation__wrapper__search__main__container__content__body__default__form__filters__content__group__list__item__label__icon" role="img"></em>
# <span class="lf-search-filters__content__group__list__item__label__text lf-modal-default__container__content__body__default__form__filters__content__group__list__item__label__text lf-search-modal__main__container__content__body__default__form__filters__content__group__list__item__label__text lf-geo-divisions__find__navigation__wrapper__search__main__container__content__body__default__form__filters__content__group__list__item__label__text">FRENCH GLOSSING</span>
# </label>
# </li>
# <li class="lf-search-filters__content__group__list__item lf-modal-default__container__content__body__default__form__filters__content__group__list__item lf-search-modal__main__container__content__body__default__form__filters__content__group__list__item lf-geo-divisions__find__navigation__wrapper__search__main__container__content__body__default__form__filters__content__group__list__item" role="option">
# <input class="lf-search-filters__content__group__list__item__input lf-modal-default__container__content__body__default__form__filters__content__group__list__item__input lf-search-modal__main__container__content__body__default__form__filters__content__group__list__item__input lf-geo-divisions__find__navigation__wrapper__search__main__container__content__body__default__form__filters__content__group__list__item__input" data-lf-filter-name="my hair [id]" data-lf-filters-category="nuestros servicios" data-lf-filters-input="" id="65c3894d7551c53329c25f72" name="filters[Nuestros servicios][]" type="checkbox" value="65c3894d7551c53329c25f72"/>
# <label class="lf-search-filters__content__group__list__item__label lf-modal-default__container__content__body__default__form__filters__content__group__list__item__label lf-search-modal__main__container__content__body__default__form__filters__content__group__list__item__label lf-geo-divisions__find__navigation__wrapper__search__main__container__content__body__default__form__filters__content__group__list__item__label" data-lf-filters-label="" for="65c3894d7551c53329c25f72">
# <em aria-labelledby="65c3894d7551c53329c25f72" class="lf-search-filters__content__group__list__item__label__icon lf-modal-default__container__content__body__default__form__filters__content__group__list__item__label__icon lf-search-modal__main__container__content__body__default__form__filters__content__group__list__item__label__icon lf-geo-divisions__find__navigation__wrapper__search__main__container__content__body__default__form__filters__content__group__list__item__label__icon" role="img"></em>
# <span class="lf-search-filters__content__group__list__item__label__text lf-modal-default__container__content__body__default__form__filters__content__group__list__item__label__text lf-search-modal__main__container__content__body__default__form__filters__content__group__list__item__label__text lf-geo-divisions__find__navigation__wrapper__search__main__container__content__body__default__form__filters__content__group__list__item__label__text">MY HAIR [iD]</span>
# </label>
# </li>
# <li class="lf-search-filters__content__group__list__item lf-modal-default__container__content__body__default__form__filters__content__group__list__item lf-search-modal__main__container__content__body__default__form__filters__content__group__list__item lf-geo-divisions__find__navigation__wrapper__search__main__container__content__body__default__form__filters__content__group__list__item" role="option">
# <input class="lf-search-filters__content__group__list__item__input lf-modal-default__container__content__body__default__form__filters__content__group__list__item__input lf-search-modal__main__container__content__body__default__form__filters__content__group__list__item__input lf-geo-divisions__find__navigation__wrapper__search__main__container__content__body__default__form__filters__content__group__list__item__input" data-lf-filter-name="inoa" data-lf-filters-category="nuestros servicios" data-lf-filters-input="" id="61b38f5c5550a6b2c1490de6" name="filters[Nuestros servicios][]" type="checkbox" value="61b38f5c5550a6b2c1490de6"/>
# <label class="lf-search-filters__content__group__list__item__label lf-modal-default__container__content__body__default__form__filters__content__group__list__item__label lf-search-modal__main__container__content__body__default__form__filters__content__group__list__item__label lf-geo-divisions__find__navigation__wrapper__search__main__container__content__body__default__form__filters__content__group__list__item__label" data-lf-filters-label="" for="61b38f5c5550a6b2c1490de6">
# <em aria-labelledby="61b38f5c5550a6b2c1490de6" class="lf-search-filters__content__group__list__item__label__icon lf-modal-default__container__content__body__default__form__filters__content__group__list__item__label__icon lf-search-modal__main__container__content__body__default__form__filters__content__group__list__item__label__icon lf-geo-divisions__find__navigation__wrapper__search__main__container__content__body__default__form__filters__content__group__list__item__label__icon" role="img"></em>
# <span class="lf-search-filters__content__group__list__item__label__text lf-modal-default__container__content__body__default__form__filters__content__group__list__item__label__text lf-search-modal__main__container__content__body__default__form__filters__content__group__list__item__label__text lf-geo-divisions__find__navigation__wrapper__search__main__container__content__body__default__form__filters__content__group__list__item__label__text">INOA</span>
# </label>
# </li>
# <li class="lf-search-filters__content__group__list__item lf-modal-default__container__content__body__default__form__filters__content__group__list__item lf-search-modal__main__container__content__body__default__form__filters__content__group__list__item lf-geo-divisions__find__navigation__wrapper__search__main__container__content__body__default__form__filters__content__group__list__item" role="option">
# <input class="lf-search-filters__content__group__list__item__input lf-modal-default__container__content__body__default__form__filters__content__group__list__item__input lf-search-modal__main__container__content__body__default__form__filters__content__group__list__item__input lf-geo-divisions__find__navigation__wrapper__search__main__container__content__body__default__form__filters__content__group__list__item__input" data-lf-filter-name="dia color" data-lf-filters-category="nuestros servicios" data-lf-filters-input="" id="65c3891ae3298c841bb9f313" name="filters[Nuestros servicios][]" type="checkbox" value="65c3891ae3298c841bb9f313"/>
# <label class="lf-search-filters__content__group__list__item__label lf-modal-default__container__content__body__default__form__filters__content__group__list__item__label lf-search-modal__main__container__content__body__default__form__filters__content__group__list__item__label lf-geo-divisions__find__navigation__wrapper__search__main__container__content__body__default__form__filters__content__group__list__item__label" data-lf-filters-label="" for="65c3891ae3298c841bb9f313">
# <em aria-labelledby="65c3891ae3298c841bb9f313" class="lf-search-filters__content__group__list__item__label__icon lf-modal-default__container__content__body__default__form__filters__content__group__list__item__label__icon lf-search-modal__main__container__content__body__default__form__filters__content__group__list__item__label__icon lf-geo-divisions__find__navigation__wrapper__search__main__container__content__body__default__form__filters__content__group__list__item__label__icon" role="img"></em>
# ...
# <span class="sr-only">Ir a la siguiente página</span>
# <em aria-hidden="true" class="lf-pagination-default__nav__list__item__icon bridge-icon-reputation-arrow-back lf-geo-divisions__top__wrapper__main__locations__pagination__nav__list__item__icon"></em>
# </a>
# </li>
# </ul>
# </nav>
# </section>
# </div>
# </div>
# </div>
# </div>
# <div class="lf-geo-divisions__main">
# </div>
# <section aria-label="Enlaces de pie de página" class="lf-geo-divisions__bottom">
# <div class="lf-breadcrumb-scroll lf-geo-divisions__bottom__breadcrumb" id="lf-breadcrumb-scroll">
# <nav aria-label="Breadcrumb" class="lf-breadcrumb-scroll__container lf-geo-divisions__bottom__breadcrumb__container" data-lf-breadcrumb-container="">
# <ol class="lf-breadcrumb-scroll__container__list lf-geo-divisions__bottom__breadcrumb__container__list" data-lf-breadcrumb-list="">
# <li class="lf-breadcrumb-scroll__container__list__item lf-geo-divisions__bottom__breadcrumb__container__list__item"><a class="lf-breadcrumb-scroll__container__list__item__link lf-geo-divisions__bottom__breadcrumb__container__list__item__link" data-lf-client-tracking="{'event': 'uaevent', 'ecommerce': 'undefined', 'eventCategory': 'salon locator', 'eventAction': 'breadcrumb click', 'breadcrumbLabel': 'home', 'event_name': 'breadcrumb_click', 'breadcrumb_label': 'home'}" data-lf-tracking='{"bind":"click","label":"Inicio","action":"","category":"Breadcrumb"}' href="/"><span class="lf-breadcrumb-scroll__container__list__item__link__label lf-geo-divisions__bottom__breadcrumb__container__list__item__link__label sr-only">
#                                 Inicio
#                             </span><em aria-hidden="true" class="lf-breadcrumb-scroll__container__list__item__link__icon lf-geo-divisions__bottom__breadcrumb__container__list__item__link__icon bridge-icon-reputation-home"></em></a></li><li class="lf-breadcrumb-scroll__container__list__item lf-geo-divisions__bottom__breadcrumb__container__list__item"><span aria-current="page" class="lf-breadcrumb-scroll__container__list__item__label lf-geo-divisions__bottom__breadcrumb__container__list__item__label">
#                             Argentina
#                         </span></li> </ol>
# </nav>
# <div class="lf-breadcrumb-scroll__overlay lf-geo-divisions__bottom__breadcrumb__overlay" data-lf-breadcrumb-overlay=""></div>
# </div>
# <script type="application/ld+json">
# {
#     "@context": "http://schema.org",
#     "@type": "BreadcrumbList",
#     "itemListElement": [            {
#             "@type": "ListItem",
#             "position": 1,
#             "item": {
#                 "@id": "/",
#                 "name": "Home"
#             }
#         },            {
#             "@type": "ListItem",
#             "position": 2,
#             "item": {
#                 "@id": "/ar",
#                 "name": "Argentina"
#             }
#         },            {
#             "@type": "ListItem",
#             "position": 3,
#             "item": {
#                 "@id": "/ar/santa-fe",
#                 "name": "Santa Fe"
#             }
#         },            {
#             "@type": "ListItem",
#             "position": 4,
#             "item": {
#                 "@id": "/ar/santa-fe/rosario",
#                 "name": "Rosario"
#             }
#         },            {
#             "@type": "ListItem",
#             "position": 5,
#             "item": {
#                 "@id": "/salones/ar/santa-fe",
#                 "name": "Santa Fe"
#             }
#         },            {
#             "@type": "ListItem",
#             "position": 6,
#             "item": {
#                 "@id": "/58848-adrian-manassero-y-rene-manassero",
#                 "name": "Adrián Manassero y René Manassero"
#             }
#         }    ]
# }
# </script>
# </section>
# </div>
# <div class="lf-parts-scroller" id="lf-scroller">
# <button class="lf-cta-button lf-cta-button--icon lf-parts-scroller__button" data-lf-scroller="" type="button">
# <em aria-hidden="true" class="lf-cta-button__icon lf-cta-button__icon--left bridge-icon-reputation-chevron-up lf-parts-scroller__button__icon lf-parts-scroller__button__icon--left"></em><span class="lf-cta-button__label sr-only lf-parts-scroller__button__label">
#                                                 Desplazarse a la parte superior de la página
#                         </span><span class="sr-only">(navegación)</span></button>
# </div> </div>
# <footer aria-label="Pie de página" data-lf-footer="" id="lf-footer">
# <div class="lf-footer-optimum">
# <div class="lf-footer-optimum__main">
# <div class="lf-footer-optimum__main__content">
# <div class="lf-footer-optimum__main__content__logo">
# <a class="lf-footer-optimum__main__content__logo__link" data-lf-client-tracking="{'event': 'uaevent', 'event_name': 'call_a_salon', 'ecommerce': 'undefined', 'eventCategory': 'main menu navigation', 'eventAction': 'select::footer', 'eventLabel': 'logo', 'event_name': 'logo_click', 'click_area': 'footer'}" href="/">
# <img alt="Logo de L’Oréal Professionnel" class="lf-footer-optimum__main__content__logo__link__img" src="https://storage.leadformance.com/assets/production-front-offices/v3-lOrealProfessionnel/v0.22.0/assets/images/footer/logo.svg" target="_blank"/>
# </a>
# </div>
# <ul class="lf-footer-optimum__main__content__social">
# <li class="lf-footer-optimum__main__content__social__item">
# <a class="lf-footer-optimum__main__content__social__item__link lf-footer-optimum__main__content__social__item__link--youtube" data-lf-client-tracking="{'event': 'socialInt', 'event_name': 'social_interaction', 'ecommerce': 'undefined', 'socialNetwork': 'youtube', 'socialAction': 'follow', 'socialTarget': 'http://salones-es.lorealprofessionnel.com/ar', 'social_network': 'youtube', 'social_action': 'follow', 'social_target': 'http://salones-es.lorealprofessionnel.com/ar'}" data-lf-tracking='{"bind":"click","label":"youtube","action":"","category":"Footer Social Links"}' href="https://www.youtube.com/user/lorealpro" rel="noopener" target="_blank">
# <span class="sr-only">Ir a la página youtube de L’Oréal Professionnel</span>
# <em alt="" aria-hidden="true" class="lf-footer-optimum__main__content__social__item__link__icon bridge-icon-brand-youtube" role="img"></em>
# </a>
# </li>
# <li class="lf-footer-optimum__main__content__social__item">
# <a class="lf-footer-optimum__main__content__social__item__link lf-footer-optimum__main__content__social__item__link--instagram" data-lf-client-tracking="{'event': 'socialInt', 'event_name': 'social_interaction', 'ecommerce': 'undefined', 'socialNetwork': 'instagram', 'socialAction': 'follow', 'socialTarget': 'http://salones-es.lorealprofessionnel.com/ar', 'social_network': 'instagram', 'social_action': 'follow', 'social_target': 'http://salones-es.lorealprofessionnel.com/ar'}" data-lf-tracking='{"bind":"click","label":"instagram","action":"","category":"Footer Social Links"}' href="https://www.instagram.com/lorealpro/" rel="noopener" target="_blank">
# <span class="sr-only">Ir a la página instagram de L’Oréal Professionnel</span>
# <em alt="" aria-hidden="true" class="lf-footer-optimum__main__content__social__item__link__icon bridge-icon-brand-instagram" role="img"></em>
# </a>
# </li>
# </ul>
# <div class="lf-footer-gdpr lf-footer-optimum__main__content__gdpr">
# <div class="lf-footer-gdpr__container lf-footer-optimum__main__content__gdpr__container">
# <ul class="lf-footer-gdpr__container__list lf-footer-optimum__main__content__gdpr__container__list">
# <li class="lf-footer-gdpr__container__list__item lf-footer-optimum__main__content__gdpr__container__list__item">
# <a class="lf-footer-gdpr__container__list__item__link lf-footer-optimum__main__content__gdpr__container__list__item__link" data-lf-tracking='{"bind":"click","label":"Legal Notice","action":"","category":"GDPR"}' href="https://www.lorealprofessionnel.com/int/legal/terms-of-use" rel="noopener" target="_blank">Legal Notice<span class="sr-only"> (Abrir en una nueva ventana)</span>
# </a>
# </li>
# <li class="lf-footer-gdpr__container__list__item lf-footer-optimum__main__content__gdpr__container__list__item">
# <a class="lf-footer-gdpr__container__list__item__link lf-footer-optimum__main__content__gdpr__container__list__item__link" data-lf-tracking='{"bind":"click","label":"Privacy Policy","action":"","category":"GDPR"}' href="https://www.lorealprofessionnel.com/int/legal/privacy-policy" rel="noopener" target="_blank">Privacy Policy<span class="sr-only"> (Abrir en una nueva ventana)</span>
# </a>
# </li>
# <li class="lf-footer-gdpr__container__list__item lf-footer-optimum__main__content__gdpr__container__list__item">
# <a class="lf-footer-gdpr__container__list__item__link lf-footer-optimum__main__content__gdpr__container__list__item__link" href="#" onclick="Optanon.ToggleInfoDisplay();">Administrar cookies </a>
# </li>
# <li class="lf-footer-gdpr__container__list__item lf-footer-optimum__main__content__gdpr__container__list__item">
# <a class="lf-wcag-contrast lf-footer-gdpr__container__list__item__link lf-footer-optimum__main__content__gdpr__container__list__item__link" data-lf-tracking='{"bind":"click","label":"Accessibility","action":"","category":"Footer"}' data-lf-wcag="" href="#" id="lf-wcag-contrast">
# <span class="lf-wcag-contrast__switch lf-footer-gdpr__container__list__item__link__switch lf-footer-optimum__main__content__gdpr__container__list__item__link__switch"></span><span class="lf-wcag-contrast__label lf-footer-gdpr__container__list__item__link__label lf-footer-optimum__main__content__gdpr__container__list__item__link__label">Versión de alto contraste
#         (<span class="lf-wcag-contrast__label__on lf-footer-gdpr__container__list__item__link__label__on lf-footer-optimum__main__content__gdpr__container__list__item__link__label__on">activar</span><span class="lf-wcag-contrast__label__off lf-footer-gdpr__container__list__item__link__label__off lf-footer-optimum__main__content__gdpr__container__list__item__link__label__off">desactivar</span>)
#     </span></a> </li>
# </ul>
# <span class="lf-footer-gdpr__container__separator lf-footer-optimum__main__content__gdpr__container__separator">-</span>
# <a class="lf-footer-gdpr__container__copyright lf-footer-optimum__main__content__gdpr__container__copyright" data-lf-tracking='{"bind":"click","label":"Bridge","action":"","category":"Copyright"}' href="https://www.solocal.com/solutions-pour-reseaux/store-locator" rel="noopener" target="_blank">
# <span class="lf-footer-gdpr__container__copyright__text">Store locator por</span>
# <img alt="__bridge.components.footer.gdpr.copyright.powered_alt" class="lf-footer-gdpr__container__copyright__logo" src="https://storage.leadformance.com/assets/production-front-offices/v3-lOrealProfessionnel/v0.22.0/assets/images/footer/logo_bridge.svg"/>
# <span class="lf-footer-gdpr__container__copyright__span sr-only"> (Abrir en una nueva ventana)</span>
# </a>
# </div>
# </div> </div>
# </div>
# </div>
# </footer>
# </div>
# </div>
# <script>window.noZensmooth = true</script>
# <script src="https://storage.leadformance.com/assets/production-front-offices/v3-lOrealProfessionnel/v0.22.0/build/geo-divisions.min.js"></script>
# <script>
#                 (function() {
#                     window.bridge.bootstrap('geoDivisions', {"globals":[],"components":{"critizr":{"active":true,"apiKey":"7f614697ac3524af3ca4ce0df9164caf"},"contactForm":{"funcs":["initModalConfig"],"recaptcha":{"active":"","container":"contact-captcha-container","siteKey":"6Ldwbz0dAAAAAIF_6T2hqw6-N4C5zFASTU4Mgbug"}},"newsletterForm":{"funcs":["initModalConfig"],"recaptcha":{"active":"","container":"newsletter-captcha-container","siteKey":"6Ldwbz0dAAAAAIF_6T2hqw6-N4C5zFASTU4Mgbug"}},"addressForm":{"funcs":["definePhoneValidation","initModalConfig"],"recaptcha":{"active":"","container":"address-captcha-container","siteKey":"6Ldwbz0dAAAAAIF_6T2hqw6-N4C5zFASTU4Mgbug"}},"geolocation":{"useGeocoding":true,"searchUrlTemplate":"\/search"},"tracking":{"keys":{"en":{"bridge":"","client":"GTM-T6CNMVB"},"fr":{"bridge":"","client":"GTM-K3J93V"},"de":{"bridge":"","client":"GTM-MX9RDR"},"el":{"bridge":"","client":"GTM-W5XTJVF"},"nl":{"bridge":"","client":"GTM-WRL6WT"},"it":{"bridge":"","client":"GTM-P8PS7Q"},"es":{"bridge":"","client":"GTM-P7QHLH"},"pt":{"bridge":"","client":"GTM-PKVWGZN"},"ar":{"bridge":"","client":"GTM-NVH6T5M"},"ro":{"bridge":"","client":"GTM-KJVQTDH"},"ja":{"bridge":"","client":"GTM-T6CNMVB"},"pl":{"bridge":"","client":"GTM-T6CNMVB"}},"didomiConfig":{"enable":false,"requireScript":false,"requireConfig":false,"vendorIds":{"bridge":"c:bridge","googleAnalytics":"c:googleanalytics","facebook":"didomi:facebook","twitter":"didomi:twitter","youtube":"c:youtube","snapwidget":"c:snapwidget"},"config":{"app":{"apiKey":"27433fae-8ff9-4a87-a579-ccc8df989c27","noticeId":"m8qBjpNh","vendors":{"didomi":["facebook","twitter"],"custom":[{"id":"youtube","name":"Youtube","policyUrl":"https:\/\/www.google.com\/intl\/en\/policies\/privacy\/","purposeIds":["cookies"]},{"id":"snapwidget","name":"Snapwidget","policyUrl":"https:\/\/snapwidget.com\/cookies","purposeIds":["cookies"]}]}},"theme":{"linkColor":"#00bfff","buttons":{"highlightButtons":{"backgroundColor":"#333","textColor":"#fff","borderColor":"#333","borderWidth":"1px","borderRadius":"0px"}}}}},"parameters":{"page":"geo-divisions-countries"}},"sliderBanner":{"options":{"autoplay":{"delay":5000},"breakpoints":null}},"sliderMedia":{"options":{"autoplay":{"delay":5000},"breakpoints":null}},"sliderBrand":{"options":{"slidesPerView":2,"spaceBetween":32,"centerInsufficientSlides":true,"breakpoints":{"600":{"slidesPerView":3,"spaceBetween":96},"992":{"slidesPerView":5,"spaceBetween":115}}}},"sliderProduct":{"options":{"slidesPerView":1,"spaceBetween":16,"autoHeight":true,"breakpoints":{"600":{"slidesPerView":2},"768":{"slidesPerView":1,"spaceBetween":32,"autoHeight":false},"1260":{"slidesPerView":2,"spaceBetween":32,"autoHeight":false}}}},"sliderNews":{"options":{"slidesPerView":1,"spaceBetween":16,"autoHeight":true,"breakpoints":{"600":{"slidesPerView":2},"768":{"slidesPerView":1,"spaceBetween":32,"autoHeight":false},"1260":{"slidesPerView":2,"spaceBetween":32,"autoHeight":false}}}},"sliderSocial":{"options":{"slidesPerView":1,"spaceBetween":16,"breakpoints":{"600":{"slidesPerView":2},"768":{"slidesPerView":1,"spaceBetween":32},"1260":{"slidesPerView":2,"spaceBetween":32}}}},"nearestStores":{"hitsPerPage":6,"searchRadius":5000,"useLocation":false,"options":{"slidesPerView":1,"spaceBetween":32,"breakpoints":{"600":{"slidesPerView":2},"992":{"slidesPerView":3}}}},"map":{"provider":"gmaps","apiKey":{"en":["gme-lorealsa","Cz_fa_vO6pGrXm7LV9yNKZCJrpA=","PPD_WE_PL_LP_PR_hair-salon-en.lorealprofessionnel.com"],"fr":["gme-lorealsa","Cz_fa_vO6pGrXm7LV9yNKZCJrpA=","PPD_WE_FR_LP_PR_salon-fr.lorealprofessionnel.com"],"de":["gme-lorealsa","Cz_fa_vO6pGrXm7LV9yNKZCJrpA=","PPD_WE_DE_LP_PR_friseur-de.lorealprofessionnel.com"],"el":["gme-lorealsa","Cz_fa_vO6pGrXm7LV9yNKZCJrpA=","PPD_WE_GR_LP_PR_kommotiria-gr.lorealprofessionnel.com"],"nl":["gme-lorealsa","Cz_fa_vO6pGrXm7LV9yNKZCJrpA=","PPD_WE_NL_LP_PR_kapper-nl.lorealprofessionnel.com"],"it":["gme-lorealsa","Cz_fa_vO6pGrXm7LV9yNKZCJrpA=","PPD_WE_IT_LP_PR_s ...
#                 })()
#             </script>
# <script>(function(){function c(){var b=a.contentDocument||a.contentWindow.document;if(b){var d=b.createElement('script');d.innerHTML="window.__CF$cv$params={r:'953fdc84fc696f9e',t:'MTc1MDYzODQ2NS4wMDAwMDA='};var a=document.createElement('script');a.nonce='';a.src='/cdn-cgi/challenge-platform/scripts/jsd/main.js';document.getElementsByTagName('head')[0].appendChild(a);";b.getElementsByTagName('head')[0].appendChild(d)}}if(document.body){var a=document.createElement('iframe');a.height=1;a.width=1;a.style.position='absolute';a.style.top=0;a.style.left=0;a.style.border='none';a.style.visibility='hidden';document.body.appendChild(a);if('loading'!==document.readyState)c();else if(window.addEventListener)document.addEventListener('DOMContentLoaded',c);else{var e=document.onreadystatechange||function(){};document.onreadystatechange=function(b){e(b);'loading'!==document.readyState&&(document.onreadystatechange=e,c())}}}})();</script></body>
# </html>

# %%
direcciones
# Out:
# ['Tucumán 973',
#  'Av. Rivadavia 2665P.A.',
#  'Paraguay 1074',
#  'Necochea 1272',
#  'Córdoba 2671',
#  'Salvador del Carril 1584',
#  'Pasteur 169',
#  'Santa Fe 54',
#  '9 de Julio 3355',
#  'Balcarce 223',
#  'Ángel Cassanello 2517',
#  'Mitre 960Loc. 18',
#  'Hipólito Irigoyen 644',
#  'Chacabuco 2056',
#  'Rivarola 8034',
#  '9 de Julio 1928',
#  'Bv. Oroño 178Bis',
#  '3 de Febrero 495',
#  '25 de Mayo 1830',
#  'Bv. Gálvez 2263Dpto. 1',
#  'Tucumán 973',
#  'Calle 50 N° 790 1/2, entre 10 y 11',
#  'Calle 51 N° 741 Entre 9 y 10',
#  'Panamericana Pilar Km. 54.500Loc. 14',
#  'Humberto Primo 778',
#  'Av. Rivadavia 2665P.A.',
#  'Merlo 2775',
#  'Av. del Sol 1141Local N° 2',
#  'Charcas 886',
#  'Arenales 486',
#  'Paraguay 1074',
#  'Necochea 1272',
#  'San Lorenzo 595',
#  'Alsina 586',
#  'San Luis 2397',
#  'Urquiza 527Loc. 2',
#  'Av. Patria 621',
#  'Ovidio Lagos 291',
#  'Alem 1211Loc. R',
#  'Ávila y Zárate 2138P.A. Depto. 5',
#  'Tucumán 973',
#  'Calle 50 N° 790 1/2, entre 10 y 11',
#  'Calle 51 N° 741 Entre 9 y 10',
#  'Panamericana Pilar Km. 54.500Loc. 14',
#  'Humberto Primo 778',
#  'Av. Rivadavia 2665P.A.',
#  'Merlo 2775',
#  'Av. del Sol 1141Local N° 2',
#  'Charcas 886',
#  'Arenales 486',
#  'Paraguay 1074',
#  'Necochea 1272',
#  'San Lorenzo 595',
#  'Alsina 586',
#  'San Luis 2397',
#  'Urquiza 527Loc. 2',
#  'Av. Patria 621',
#  'Ovidio Lagos 291',
#  'Alem 1211Loc. R',
#  'Ávila y Zárate 2138P.A. Depto. 5',
#  'Tucumán 973',
#  'Calle 50 N° 790 1/2, entre 10 y 11',
#  'Calle 51 N° 741 Entre 9 y 10',
#  'Panamericana Pilar Km. 54.500Loc. 14',
#  'Humberto Primo 778',
#  'Av. Rivadavia 2665P.A.',
#  'Merlo 2775',
#  'Av. del Sol 1141Local N° 2',
#  'Charcas 886',
#  'Arenales 486',
#  'Paraguay 1074',
#  'Necochea 1272',
#  'San Lorenzo 595',
#  'Alsina 586',
#  'San Luis 2397',
#  'Urquiza 527Loc. 2',
#  'Av. Patria 621',
#  'Ovidio Lagos 291',
#  'Alem 1211Loc. R',
#  'Ávila y Zárate 2138P.A. Depto. 5',
#  'Tucumán 973',
#  'Calle 50 N° 790 1/2, entre 10 y 11',
#  'Calle 51 N° 741 Entre 9 y 10',
#  'Panamericana Pilar Km. 54.500Loc. 14',
#  'Humberto Primo 778',
#  'Av. Rivadavia 2665P.A.',
#  'Merlo 2775',
#  'Av. del Sol 1141Local N° 2',
#  'Charcas 886',
#  'Arenales 486',
#  'Paraguay 1074',
#  'Necochea 1272',
#  'San Lorenzo 595',
#  'Alsina 586',
#  'San Luis 2397',
#  'Urquiza 527Loc. 2',
#  'Av. Patria 621',
#  'Ovidio Lagos 291',
#  'Alem 1211Loc. R',
#  'Ávila y Zárate 2138P.A. Depto. 5',
#  'Tucumán 973',
#  'Calle 50 N° 790 1/2, entre 10 y 11',
#  'Calle 51 N° 741 Entre 9 y 10',
#  'Panamericana Pilar Km. 54.500Loc. 14',
#  'Humberto Primo 778',
#  'Av. Rivadavia 2665P.A.',
#  'Merlo 2775',
#  'Av. del Sol 1141Local N° 2',
#  'Charcas 886',
#  'Arenales 486',
#  'Paraguay 1074',
#  'Necochea 1272',
#  'San Lorenzo 595',
#  'Alsina 586',
#  'San Luis 2397',
#  'Urquiza 527Loc. 2',
#  'Av. Patria 621',
#  'Ovidio Lagos 291',
#  'Alem 1211Loc. R',
#  'Ávila y Zárate 2138P.A. Depto. 5',
#  'Tucumán 973',
#  'Calle 50 N° 790 1/2, entre 10 y 11',
#  'Calle 51 N° 741 Entre 9 y 10',
#  'Panamericana Pilar Km. 54.500Loc. 14',
#  'Humberto Primo 778',
#  'Av. Rivadavia 2665P.A.',
#  'Merlo 2775',
#  'Av. del Sol 1141Local N° 2',
#  'Charcas 886',
#  'Arenales 486',
#  'Paraguay 1074',
#  'Necochea 1272',
#  'San Lorenzo 595',
#  'Alsina 586',
#  'San Luis 2397',
#  'Urquiza 527Loc. 2',
#  'Av. Patria 621',
#  'Ovidio Lagos 291',
#  'Alem 1211Loc. R',
#  'Ávila y Zárate 2138P.A. Depto. 5',
#  'Tucumán 973',
#  'Calle 50 N° 790 1/2, entre 10 y 11',
#  'Calle 51 N° 741 Entre 9 y 10',
#  'Panamericana Pilar Km. 54.500Loc. 14',
#  'Humberto Primo 778',
#  'Av. Rivadavia 2665P.A.',
#  'Merlo 2775',
#  'Av. del Sol 1141Local N° 2',
#  'Charcas 886',
#  'Arenales 486',
#  'Paraguay 1074',
#  'Necochea 1272',
#  'San Lorenzo 595',
#  'Alsina 586',
#  'San Luis 2397',
#  'Urquiza 527Loc. 2',
#  'Av. Patria 621',
#  'Ovidio Lagos 291',
#  'Alem 1211Loc. R',
#  'Ávila y Zárate 2138P.A. Depto. 5']

# %%
nombres
# Out:
# ['Adrián Manassero y René Manassero',
#  'Cristina Gibert Peinados',
#  'Dante Peluquería',
#  'Darío Estilista',
#  'Emilio Coiffeur Unisex',
#  'Estela Peinados',
#  'Evolution Peluqueria unsex',
#  'Germán Cilfono Estilista',
#  'Gemmas Peluquería',
#  'Glamorosas Salón de Peinados',
#  'Gustavo Bordon Innova',
#  'Guappas Peluquería',
#  'Graciela Salón',
#  'Haydee Peluquería Unisex',
#  'Imag"n',
#  'Irma Peinados',
#  'Isabel Peluquería',
#  "J'Look",
#  'Jobson Debona',
#  'José Bonfanti Peinados',
#  'Adrián Manassero y René Manassero',
#  'Actitud S.H.',
#  'Coop. de Trabajo Stylo Propio Limit',
#  "Comb N' Brush",
#  'Covato Pablo Gabriel',
#  'Cristina Gibert Peinados',
#  'Crifaci Edgar Flavio',
#  'Cynthia pizarro Estilista',
#  'Cristina Andia',
#  'DA RU ME Peinados',
#  'Dante Peluquería',
#  'Darío Estilista',
#  'Daniel Dominguez Estilista',
#  'Di Amore',
#  'Diego Enrique',
#  'Diana Chaves',
#  'Diegrafel',
#  'E.R.  Peluquería',
#  'Donnato Peluquería',
#  'Día Peluquería',
#  'Adrián Manassero y René Manassero',
#  'Actitud S.H.',
#  'Coop. de Trabajo Stylo Propio Limit',
#  "Comb N' Brush",
#  'Covato Pablo Gabriel',
#  'Cristina Gibert Peinados',
#  'Crifaci Edgar Flavio',
#  'Cynthia pizarro Estilista',
#  'Cristina Andia',
#  'DA RU ME Peinados',
#  'Dante Peluquería',
#  'Darío Estilista',
#  'Daniel Dominguez Estilista',
#  'Di Amore',
#  'Diego Enrique',
#  'Diana Chaves',
#  'Diegrafel',
#  'E.R.  Peluquería',
#  'Donnato Peluquería',
#  'Día Peluquería',
#  'Adrián Manassero y René Manassero',
#  'Actitud S.H.',
#  'Coop. de Trabajo Stylo Propio Limit',
#  "Comb N' Brush",
#  'Covato Pablo Gabriel',
#  'Cristina Gibert Peinados',
#  'Crifaci Edgar Flavio',
#  'Cynthia pizarro Estilista',
#  'Cristina Andia',
#  'DA RU ME Peinados',
#  'Dante Peluquería',
#  'Darío Estilista',
#  'Daniel Dominguez Estilista',
#  'Di Amore',
#  'Diego Enrique',
#  'Diana Chaves',
#  'Diegrafel',
#  'E.R.  Peluquería',
#  'Donnato Peluquería',
#  'Día Peluquería',
#  'Adrián Manassero y René Manassero',
#  'Actitud S.H.',
#  'Coop. de Trabajo Stylo Propio Limit',
#  "Comb N' Brush",
#  'Covato Pablo Gabriel',
#  'Cristina Gibert Peinados',
#  'Crifaci Edgar Flavio',
#  'Cynthia pizarro Estilista',
#  'Cristina Andia',
#  'DA RU ME Peinados',
#  'Dante Peluquería',
#  'Darío Estilista',
#  'Daniel Dominguez Estilista',
#  'Di Amore',
#  'Diego Enrique',
#  'Diana Chaves',
#  'Diegrafel',
#  'E.R.  Peluquería',
#  'Donnato Peluquería',
#  'Día Peluquería',
#  'Adrián Manassero y René Manassero',
#  'Actitud S.H.',
#  'Coop. de Trabajo Stylo Propio Limit',
#  "Comb N' Brush",
#  'Covato Pablo Gabriel',
#  'Cristina Gibert Peinados',
#  'Crifaci Edgar Flavio',
#  'Cynthia pizarro Estilista',
#  'Cristina Andia',
#  'DA RU ME Peinados',
#  'Dante Peluquería',
#  'Darío Estilista',
#  'Daniel Dominguez Estilista',
#  'Di Amore',
#  'Diego Enrique',
#  'Diana Chaves',
#  'Diegrafel',
#  'E.R.  Peluquería',
#  'Donnato Peluquería',
#  'Día Peluquería',
#  'Adrián Manassero y René Manassero',
#  'Actitud S.H.',
#  'Coop. de Trabajo Stylo Propio Limit',
#  "Comb N' Brush",
#  'Covato Pablo Gabriel',
#  'Cristina Gibert Peinados',
#  'Crifaci Edgar Flavio',
#  'Cynthia pizarro Estilista',
#  'Cristina Andia',
#  'DA RU ME Peinados',
#  'Dante Peluquería',
#  'Darío Estilista',
#  'Daniel Dominguez Estilista',
#  'Di Amore',
#  'Diego Enrique',
#  'Diana Chaves',
#  'Diegrafel',
#  'E.R.  Peluquería',
#  'Donnato Peluquería',
#  'Día Peluquería',
#  'Adrián Manassero y René Manassero',
#  'Actitud S.H.',
#  'Coop. de Trabajo Stylo Propio Limit',
#  "Comb N' Brush",
#  'Covato Pablo Gabriel',
#  'Cristina Gibert Peinados',
#  'Crifaci Edgar Flavio',
#  'Cynthia pizarro Estilista',
#  'Cristina Andia',
#  'DA RU ME Peinados',
#  'Dante Peluquería',
#  'Darío Estilista',
#  'Daniel Dominguez Estilista',
#  'Di Amore',
#  'Diego Enrique',
#  'Diana Chaves',
#  'Diegrafel',
#  'E.R.  Peluquería',
#  'Donnato Peluquería',
#  'Día Peluquería']

# %%
dic = {'Nombre': nombres, 'Dirección': direcciones}
df = pd.DataFrame(dic)

# %%
df.head()
# Out:
#                               Nombre               Dirección
# 0  Adrián Manassero y René Manassero             Tucumán 973
# 1           Cristina Gibert Peinados  Av. Rivadavia 2665P.A.
# 2                   Dante Peluquería           Paraguay 1074
# 3                    Darío Estilista           Necochea 1272
# 4             Emilio Coiffeur Unisex            Córdoba 2671
